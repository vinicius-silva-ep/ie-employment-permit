# %% [markdown]
# 2024 - Employment Permit by Sector

# %%
year = 2024

# Reading the raw data in the folder on my personal computer
import pandas as pd 

df = pd.read_excel(f"E:/My Drive/ESTUDOS DATA SCIENCE/ie-employment-permit/data/raw_data/{year}/permits-by-sector-{year}.xlsx",
                   header=0,
                  #  skiprows=[1, 2] # I needed to skip these rows because I had the summarization of the values by year (which was uninteresting)
)
print(df)
# Out:
#                                       Economic Sector  Unnamed: 1     Jan  \
# 0                 A - Agriculture, Forestry & Fishing        3625   252.0
# 1                              B - Mining & Quarrying          37     2.0
# 2                         C - All Other Manufacturing         981    58.0
# 3      C - Manufacture of Chemicals & Pharmaceuticals         829    69.0
# 4   C - Manufacture of Computers, Electronics & Op...         570    47.0
# 5            C - Manufacture of Food, Drink & Tobacco         353    41.0
# 6                  C - Manufacture of Medical Devices         289    36.0
# 7     D - Electricity & Gas & Air Conditioning Supply         463    41.0
# 8   E - Water Supply - Sewerage Waste Management &...          85    10.0
# 9                                    F - Construction        1523    96.0
# 10                       G - Wholesale & Retail Trade         441    33.0
# 11                            H - Transport & Storage        1282    78.0
# 12       I - Accommodation & Food Services activities        3358   226.0
# 13         J - Information & Communication Activities        6788   592.0
# 14               K - Financial & insurance Activities        2318   162.0
# 15                         L - Real Estate Activities          24     4.0
# 16  M - All other Professional, Scientific & Techn...         806    73.0
# 17  M - Professional, Scientific&Technical Activities         286    13.0
# 18    N - Administrative & Support Service Activities          89     5.0
# 19                O - Public Administration & Defence          23     1.0
# 20                                      P - Education         357    22.0
# 21                Q - Health & Social Work Activities       12501  1431.0
# 22            R - Arts , Entertainment and Recreation         586    18.0
# 23                       S - Other Service activities        1772   113.0
# 24  T - Domestic- Activities of Households as Empl...           3     NaN
#
#        Feb   Mar   Apr    May     Jun     Jul    Aug    Sep    Oct     Nov  \
# 0    591.0   158   205  372.0   281.0   402.0  272.0  412.0  346.0   141.0
# 1      2.0     4     4    3.0     4.0     1.0    4.0    3.0    1.0     6.0
# 2    107.0    49    96   91.0    75.0   117.0   76.0   83.0   66.0    71.0
# 3     56.0    60    66   56.0    56.0   105.0   81.0   44.0   65.0    81.0
# 4     50.0    24    78   31.0    41.0    80.0   30.0   38.0   47.0    59.0
# 5     47.0    27    44   16.0    23.0    38.0   28.0   24.0   21.0    31.0
# 6     23.0    11    62   14.0    19.0    40.0   13.0   11.0   13.0    31.0
# 7     34.0    35    53   27.0    43.0    33.0   53.0   41.0   47.0    30.0
# 8     13.0     9     1    3.0     4.0    14.0   10.0    8.0    4.0     3.0
# 9     87.0    79   133  148.0   120.0   173.0  138.0  128.0  123.0   140.0
# 10    43.0    19    21   41.0    58.0    40.0   46.0   29.0   36.0    37.0
# 11    68.0    38   108  133.0   109.0   143.0  174.0   77.0  129.0   137.0
# 12   279.0   131   291  343.0   188.0   395.0  385.0  254.0  292.0   297.0
# 13   511.0   601   663  374.0   541.0   753.0  594.0  538.0  472.0   572.0
# 14   149.0   235   182  140.0   167.0   245.0  237.0  227.0  192.0   211.0
# 15     2.0     3     2    1.0     2.0     4.0    1.0    NaN    1.0     4.0
# 16    76.0    94    75   60.0    46.0    74.0   65.0   43.0   51.0    73.0
# 17    17.0    17    16   12.0    16.0    31.0   21.0   35.0   22.0    33.0
# 18    10.0     6     8   10.0     7.0     7.0   10.0    4.0    9.0     6.0
# 19     2.0     3     5    NaN     NaN     NaN    2.0    2.0    4.0     4.0
# 20    38.0    17    30   20.0    22.0    26.0   43.0   32.0   35.0    37.0
# 21  1089.0  1211  1145  872.0  1056.0  1476.0  843.0  777.0  751.0  1042.0
# 22    44.0    39    79   51.0    37.0    85.0   33.0   60.0   39.0    62.0
# 23   115.0    87   140  117.0   104.0   237.0  204.0  119.0  180.0   178.0
# 24     NaN     2     1    NaN     NaN     NaN    NaN    NaN    NaN     NaN
#
#       Dec
# 0   193.0
# 1     3.0
# 2    92.0
# 3    90.0
# 4    45.0
# 5    13.0
# 6    16.0
# 7    26.0
# 8     7.0
# 9   158.0
# 10   38.0
# 11   88.0
# 12  277.0
# 13  577.0
# 14  171.0
# 15    NaN
# 16   76.0
# 17   53.0
# 18    7.0
# 19    NaN
# 20   35.0
# 21  808.0
# 22   39.0
# 23  178.0
# 24    NaN

# %%
# Creating a new column
df['Year'] = f"{year}"


# I had to pivot the table and sort by year, month and sector
df_melted = df.melt(
    id_vars=['Economic Sector', 'Year'],
    value_vars=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun',
                'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'],
    var_name='Month',
    value_name='Issued'
)

# Renaming again to make the df tidy
df = df_melted
df = df.rename(columns={'Economic Sector': 'Sector'})
df = df[['Year', 'Month', 'Sector', 'Issued']]

# Creating new columns because from 2009-2019 the dataset got refused and withdrawn values, after 2020 we have only issued "total"
df['Refused'] = ''
df['Withdrawn'] = ''

# %%
# I used the extension .csv because is lighter and easy to work with some libraries like pandas, sqlalchemy
df.to_csv(f"E:/My Drive/ESTUDOS DATA SCIENCE/ie-employment-permit/data/{year}/permits-by-sector-{year}.csv", index=False)

print(df)
# Out:
#      Year Month                                             Sector  Issued  \
# 0    2024   Jan                A - Agriculture, Forestry & Fishing   252.0
# 1    2024   Jan                             B - Mining & Quarrying     2.0
# 2    2024   Jan                        C - All Other Manufacturing    58.0
# 3    2024   Jan     C - Manufacture of Chemicals & Pharmaceuticals    69.0
# 4    2024   Jan  C - Manufacture of Computers, Electronics & Op...    47.0
# ..    ...   ...                                                ...     ...
# 295  2024   Dec                                      P - Education    35.0
# 296  2024   Dec                Q - Health & Social Work Activities   808.0
# 297  2024   Dec            R - Arts , Entertainment and Recreation    39.0
# 298  2024   Dec                       S - Other Service activities   178.0
# 299  2024   Dec  T - Domestic- Activities of Households as Empl...     NaN
#
#     Refused Withdrawn
# 0
# 1
# 2
# 3
# 4
# ..      ...       ...
# 295
# 296
# 297
# 298
# 299
#
# [300 rows x 6 columns]
